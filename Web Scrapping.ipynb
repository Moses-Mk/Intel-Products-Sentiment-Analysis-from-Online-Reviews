# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

headers = {
    'authority': 'www.amazon.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9,bn;q=0.8',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Google Chrome";v="102"',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'
}

reviews_url = 'https://www.amazon.com/Intel-i5-13600KF-Desktop-Processor-P-cores/dp/B0BCF5CZ16/ref=sr_1_9?crid=3T1HK1JCBJB5C&dib=eyJ2IjoiMSJ9.NjW4u06ZDPSjk1XiQIiwF1JoDVwT_YkiUR3BxeGPgmBDeBl6fw4BW453cTwMK80msJOcdkHwy4B6tgER9yWaRmHKkU7-OOa_GEpI8_c0Uzw3fZqop7LXCx16KufctVWUML-UmQ8wxL2Z-31ElMck27OPcSUbTq54Rtnlb24Xlbx9exPyr5tao1NOMkua4AhZvxSXGSoBEhjzhwZYxCOpF6bTxQd5DEKavO6Cw9nczsk.td8xttJx7tNUeAja1WRsX32w3ua0PvRqZqLRID52cMI&dib_tag=se&keywords=intel&qid=1720506772&sprefix=in%2Caps%2C376&sr=8-9'

len_page = 2

def reviewsHtml(url, len_page):
    soups = []
    for page_no in range(1, len_page + 1):
        params = {
            'ie': 'UTF8',
            'reviewerType': 'all_reviews',
            'filterByStar': 'critical',
            'pageNumber': page_no,
        }
        response = requests.get(url, headers=headers, verify=False)
        soup = BeautifulSoup(response.text, 'lxml')
        soups.append(soup)
    return soups

def getReviews(html_data):
    data_dicts = []
    boxes = html_data.select('div[data-hook="review"]')
    for box in boxes:
        try:
            name = box.select_one('[class="a-profile-name"]').text.strip()
        except Exception as e:
            name = 'N/A'

        try:
            stars = box.select_one('[data-hook="review-star-rating"]').text.strip().split(' out')[0]
        except Exception as e:
            stars = 'N/A'   

        try:
            title = box.select_one('[data-hook="review-title"]').text.strip()
        except Exception as e:
            title = 'N/A'

        try:
            datetime_str = box.select_one('[data-hook="review-date"]').text.strip().split(' on ')[-1]
            date = datetime.strptime(datetime_str, '%B %d, %Y').strftime("%d/%m/%Y")
        except Exception as e:
            date = 'N/A'

        try:
            description = box.select_one('[data-hook="review-body"]').text.strip()
        except Exception as e:
            description = 'N/A'

        data_dict = {
            'Name': name,
            'Stars': stars,
            'Title': title,
            'Date': date,
            'Description': description
        }
        data_dicts.append(data_dict)
    return data_dicts

html_datas = reviewsHtml(reviews_url, len_page)

reviews = []
for html_data in html_datas:
    review = getReviews(html_data)
    reviews += review

df_reviews = pd.DataFrame(reviews)

print(df_reviews)

# Save data
df_reviews.to_csv('reviews.csv', index=False)
# Out:
# C:\Users\Moses Makwei\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.amazon.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\Moses Makwei\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.amazon.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#                 Name Stars                                              Title  \
# 0             YALE70   5.0  5.0 out of 5 stars\nThe performance bargain of...
# 1           Vladimir   5.0           5.0 out of 5 stars\nWhat an amazing CPU!
# 2      Evan Herriges   5.0        5.0 out of 5 stars\nAmazingly underated cpu
# 3    Amazon Customer   5.0          5.0 out of 5 stars\nComing from i5 12400f
# 4   Clinton Peterson   5.0             5.0 out of 5 stars\nGreat performance!
# 5      D. Villanueva   5.0  5.0 out of 5 stars\nPerfect processor for thos...
# 6            monkous   4.0      4.0 out of 5 stars\nswapped from amd to intel
# 7      Connor Loomis   5.0               5.0 out of 5 stars\nGreat for gaming
# 8        Fernando M.   N/A                                          Excelente
# 9            Joselma   N/A                                 Rápido e eficiente
# 10               Sam   N/A                                      Great Upgrade
# 11            Carlos   N/A                               A funcionar em pleno
# 12         M.Hopkins   N/A                                           Intel I5
# 13            YALE70   5.0  5.0 out of 5 stars\nThe performance bargain of...
# 14          Vladimir   5.0           5.0 out of 5 stars\nWhat an amazing CPU!
# 15     Evan Herriges   5.0        5.0 out of 5 stars\nAmazingly underated cpu
# 16   Amazon Customer   5.0          5.0 out of 5 stars\nComing from i5 12400f
# 17  Clinton Peterson   5.0             5.0 out of 5 stars\nGreat performance!
# 18     D. Villanueva   5.0  5.0 out of 5 stars\nPerfect processor for thos...
# 19           monkous   4.0      4.0 out of 5 stars\nswapped from amd to intel
# 20     Connor Loomis   5.0               5.0 out of 5 stars\nGreat for gaming
# 21       Fernando M.   N/A                                          Excelente
# 22           Joselma   N/A                                 Rápido e eficiente
# 23               Sam   N/A                                      Great Upgrade
# 24            Carlos   N/A                               A funcionar em pleno
# 25         M.Hopkins   N/A                                           Intel I5
#
#           Date                                        Description
# 0   22/02/2023  I won't go into much technical detail here sin...
# 1   28/03/2024  Using it with arctic freezer 34, even overcloc...
# 2   01/06/2024  Been using this cpu for about a year now and i...
# 3   11/04/2024  I was on the fence about upgrading from i5 124...
# 4   04/05/2024  No issues, added to my system after having an ...
# 5   30/04/2024  If you looking for a processor that won't brea...
# 6   13/05/2024  went from ryzen 5800x to this and i do not reg...
# 7   23/03/2024  Currently I have this cpu and my 4070ti connec...
# 8   12/06/2024  Muy buen precio, y entrega rapida y segura.\nR...
# 9   06/05/2024  Símplismente o melhor processador da geração I...
# 10  13/01/2024  Upgrading to the Intel Core i5-13600KF Desktop...
# 11  26/06/2024  A caixa estava danificada, mas o processador v...
# 12  03/04/2024  Out of all the Intel CPU,s the 13th gen I5’s d...
# 13  22/02/2023  I won't go into much technical detail here sin...
# 14  28/03/2024  Using it with arctic freezer 34, even overcloc...
# 15  01/06/2024  Been using this cpu for about a year now and i...
# 16  11/04/2024  I was on the fence about upgrading from i5 124...
# 17  04/05/2024  No issues, added to my system after having an ...
# 18  30/04/2024  If you looking for a processor that won't brea...
# 19  13/05/2024  went from ryzen 5800x to this and i do not reg...
# 20  23/03/2024  Currently I have this cpu and my 4070ti connec...
# 21  12/06/2024  Muy buen precio, y entrega rapida y segura.\nR...
# 22  06/05/2024  Símplismente o melhor processador da geração I...
# 23  13/01/2024  Upgrading to the Intel Core i5-13600KF Desktop...
# 24  26/06/2024  A caixa estava danificada, mas o processador v...
# 25  03/04/2024  Out of all the Intel CPU,s the 13th gen I5’s d...

# %%
import pandas as pd

input_jsonl = r"D:\Electronics.jsonl"
output_csv = 'intel_processor_reviews2.csv'


filtered_data = pd.DataFrame(columns=["user_id", "asin", "rating", "helpful_vote", "verified_purchase", "text"])


chunksize = 10000  
max_reviews = 1500 
total_filtered = 0

with open(input_jsonl, 'r', encoding='utf-8') as file:
    chunk = []
    for i, line in enumerate(file):
        chunk.append(line)
        if (i + 1) % chunksize == 0:
            df_chunk = pd.read_json(''.join(chunk), lines=True)
            filtered_chunk = df_chunk[df_chunk['text'].str.contains('Intel', case=False, na=False)]
            filtered_chunk = filtered_chunk[["user_id", "asin", "rating", "helpful_vote", "verified_purchase", "text"]]
            filtered_data = pd.concat([filtered_data, filtered_chunk], ignore_index=True)
            total_filtered += len(filtered_chunk)
            chunk = []
            if total_filtered >= max_reviews:
                break

    if chunk and total_filtered < max_reviews:
        df_chunk = pd.read_json(''.join(chunk), lines=True)
        filtered_chunk = df_chunk[df_chunk['text'].str.contains('Intel', case=False, na=False)]
        filtered_chunk = filtered_chunk[["user_id", "asin", "rating", "helpful_vote", "verified_purchase", "text"]]
        filtered_data = pd.concat([filtered_data, filtered_chunk], ignore_index=True)
        total_filtered += len(filtered_chunk)


filtered_data = filtered_data.head(max_reviews)

# Saving the filtered data to a new CSV file
filtered_data.to_csv(output_csv, index=False)

print(f"Filtered data containing 'Intel' has been saved to '{output_csv}'.")
# Out:
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# C:\Users\Moses Makwei\AppData\Local\Temp\ipykernel_24840\2677550161.py:19: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_chunk = pd.read_json(''.join(chunk), lines=True)
# Filtered data containing 'Intel' has been saved to 'intel_processor_reviews2.csv'.
